# %%
pip install gradio_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 5.2 MB/s eta 0:00:00
# ...

# %%
from gradio_client import Client

client = Client("https://8c1d25bce23ab9b328.gradio.live/")
result = client.predict(
    age="45",   # Corrected input: integer as string
    sex="0",
    cp="1",
    trestbps="100",
    chol="200",
    fbs="0",
    restecg="1",
    thalach="120",
    exang="0",
    oldpeak="1.5",
    slope="2",
    ca="0",
    thal="2"
)

print(result)
# Out:
# Loaded as API: https://8c1d25bce23ab9b328.gradio.live/ ✔
# The person is not diabetic
